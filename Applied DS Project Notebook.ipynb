# %% [markdown]
# ## Capstone Project Notebook

# %% [markdown]
# #### This notebook will be used for the IBM APPLIED DATA SCIENCE PROJECT

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %%
Test = 2
