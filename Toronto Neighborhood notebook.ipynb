# %% [markdown]
# ## Toronto Neighbourhood data

# %% [markdown]
# #### intall and import libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !pip install geopy

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
from pandas.io.html import read_html

# %% [markdown]
# #### read the Canada postal code Wiki web page

# %%
page = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

wikitables = read_html(page,  attrs={"class":"wikitable"})

print ("Extracted {num} wikitables".format(num=len(wikitables)))
# Out:
# Extracted 1 wikitables

# %% [markdown]
# #### read the Toronto data into pandas DataFrame

# %%
toronto_df = pd.DataFrame(wikitables[0])
toronto_df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# #### check DataFrame's dimms

# %%
toronto_df.shape
# Out:
# (288, 3)

# %% [markdown]
# #### keep only valid rows, ignore the 'Not assigned' Borough values

# %%
toronto_df = toronto_df[toronto_df['Borough']!= 'Not assigned']
toronto_df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %% [markdown]
# #### groupby postcode and Borough to join the multiple Neighbourhood values into single one

# %%
toronto_df_group = toronto_df.groupby(['Postcode', 'Borough'])['Neighbourhood'].agg(', '.join).reset_index(name='Neighbourhood')

# %% [markdown]
# #### check again

# %%
toronto_df_group.shape
# Out:
# (103, 3)

# %% [markdown]
# #### On M7A postcode

# %%
for index, row in toronto_df_group.iterrows():
    if value['Neighbourhood'] == 'Not assigned':
        new_value = value['Borough']
        value['Neighbourhood'] = new_value

# %% [markdown]
# #### check the M7A postcode

# %%
toronto_df_group[toronto_df_group['Postcode'] == 'M7A']
# Out:
#    Postcode       Borough Neighbourhood
# 85      M7A  Queen's Park  Queen's Park

# %%
CLIENT_ID = 'ZISPWCOUB0LBELFZ1MZVW5PATP4J4SRMYNJ5WRYEWMIJXD3P' # your Foursquare ID
CLIENT_SECRET = 'BRGEUPNWAKXALC4NN1UEL0AOFZZBQH5OELNDN4FSKNKQFICC' # your Foursquare Secret
VERSION = '20191024'  #20180604
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZISPWCOUB0LBELFZ1MZVW5PATP4J4SRMYNJ5WRYEWMIJXD3P
# CLIENT_SECRET:BRGEUPNWAKXALC4NN1UEL0AOFZZBQH5OELNDN4FSKNKQFICC

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="foursquare_agent", timeout=3)

location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %%
for index, row in toronto_df_group.iterrows():
    address = row['Borough']
    geolocator = Nominatim(user_agent="foursquare_agent", timeout=3)
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    toronto_df_group['latidude'] = latitude
    toronto_df_group['longitude'] = longitude

# %%
toronto_df_group
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# 31       M3L        North York
# 32       M3M        North York
# 33       M3N        North York
# 34       M4A        North York
# 35       M4B         East York
# 36       M4C         East York
# 37       M4E      East Toronto
# 38       M4G         East York
# 39       M4H         East York
# 40       M4J         East York
# 41       M4K      East Toronto
# 42       M4L      East Toronto
# 43       M4M      East Toronto
# 44       M4N   Central Toronto
# 45       M4P   Central Toronto
# 46       M4R   Central Toronto
# 47       M4S   Central Toronto
# 48       M4T   Central Toronto
# 49       M4V   Central Toronto
# 50       M4W  Downtown Toronto
# 51       M4X  Downtown Toronto
# 52       M4Y  Downtown Toronto
# 53       M5A  Downtown Toronto
# 54       M5B  Downtown Toronto
# 55       M5C  Downtown Toronto
# 56       M5E  Downtown Toronto
# 57       M5G  Downtown Toronto
# 58       M5H  Downtown Toronto
Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.671459 -79.552492
# 50                                            Rosedale  43.671459 -79.552492
# 51                         Cabbagetown, St. James Town  43.671459 -79.552492
# 52                                Church and Wellesley  43.671459 -79.552492
# 53                           Harbourfront, Regent Park  43.671459 -79.552492
# 54                            Ryerson, Garden District  43.671459 -79.552492
# 55                                      St. James Town  43.671459 -79.552492
# 56                                         Berczy Park  43.671459 -79.552492
# 57                                  Central Bay Street  43.671459 -79.552492
# 58                            Adelaide, King, Richmond  43.671459 -79.552492
# 59   Harbourfront East, Toronto Islands, Union Station  43.671459 -79.552492
# 60            Design Exchange, Toronto Dominion Centre  43.671459 -79.552492
# 61                      Commerce Court, Victoria Hotel  43.671459 -79.552492
# 62                   Bedford Park, Lawrence Manor East  43.671459 -79.552492
# 63                                            Roselawn  43.671459 -79.552492
# 64                 Forest Hill North, Forest Hill West  43.671459 -79.552492
# 65                 The Annex, North Midtown, Yorkville  43.671459 -79.552492
# 66                      Harbord, University of Toronto  43.671459 -79.552492
# 67           Chinatown, Grange Park, Kensington Market  43.671459 -79.552492
# 68   CN Tower, Bathurst Quay, Island airport, Harbo...  43.671459 -79.552492
# 69                     Stn A PO Boxes 25 The Esplanade  43.671459 -79.552492
# 70              First Canadian Place, Underground city  43.671459 -79.552492
# 71                    Lawrence Heights, Lawrence Manor  43.671459 -79.552492
# 72                                           Glencairn  43.671459 -79.552492
# 73                                  Humewood-Cedarvale  43.671459 -79.552492
# 74                                 Caledonia-Fairbanks  43.671459 -79.552492
# 75                                            Christie  43.671459 -79.552492
# 76                        Dovercourt Village, Dufferin  43.671459 -79.552492
# 77                            Little Portugal, Trinity  43.671459 -79.552492
# 78        Brockton, Exhibition Place, Parkdale Village  43.671459 -79.552492
# 79                  Downsview, North Park, Upwood Park  43.671459 -79.552492
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.671459 -79.552492
# 81                       The Junction North, Runnymede  43.671459 -79.552492
# 82                       High Park, The Junction South  43.671459 -79.552492
# 83                              Parkdale, Roncesvalles  43.671459 -79.552492
# 84                                  Runnymede, Swansea  43.671459 -79.552492
# 85                                        Queen's Park  43.671459 -79.552492
# 86               Canada Post Gateway Processing Centre  43.671459 -79.552492
# 87   Business Reply Mail Processing Centre 969 Eastern  43.671459 -79.552492
# 88        Humber Bay Shores, Mimico South, New Toronto  43.671459 -79.552492
# 89                              Alderwood, Long Branch  43.671459 -79.552492
# 90       The Kingsway, Montgomery Road, Old Mill North  43.671459 -79.552492
# 91   Humber Bay, King's Mill Park, Kingsway Park So...  43.671459 -79.552492
# 92   Kingsway Park South West, Mimico NW, The Queen...  43.671459 -79.552492
# 93                                    Islington Avenue  43.671459 -79.552492
# 94   Cloverdale, Islington, Martin Grove, Princess ...  43.671459 -79.552492
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.671459 -79.552492
# 96                                       Humber Summit  43.671459 -79.552492
# 97                                    Emery, Humberlea  43.671459 -79.552492
# 98                                              Weston  43.671459 -79.552492
# 99                                           Westmount  43.671459 -79.552492
# 100  Kingsview Village, Martin Grove Gardens, Richv...  43.671459 -79.552492
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...  43.671459 -79.552492
# 102                                          Northwest  43.671459 -79.552492
